# %%
# Installing the packages
# !pip install folium
# !pip install IPython
# !pip install geocoder
# !pip install geopy
# !pip install vega_datasets
# Out:
# Requirement already satisfied: folium in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: branca>=0.3.0 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from folium) (0.5.0)
# Requirement already satisfied: numpy in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: IPython in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (8.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (0.18.1)
# Requirement already satisfied: stack-data in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (61.2.0)
# Requirement already satisfied: pickleshare in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: backcall in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: decorator in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: pure-eval in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: asttokens in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: executing in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: six in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from asttokens->stack-data->IPython) (1.16.0)
# Requirement already satisfied: geocoder in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (1.38.1)
# Requirement already satisfied: future in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: ratelim in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from geocoder) (8.0.4)
# Requirement already satisfied: six in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: requests in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from geocoder) (2.27.1)
# Requirement already satisfied: decorator in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (2021.10.8)
# Requirement already satisfied: geopy in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from geopy) (1.52)
# Requirement already satisfied: vega_datasets in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: pandas in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from vega_datasets) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from pandas->vega_datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from pandas->vega_datasets) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from pandas->vega_datasets) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/meta-sapien/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->vega_datasets) (1.16.0)

# %%
from IPython.display import IFrame
documentation = IFrame('https://python-visualization.github.io/folium/',width = 1000, height = 500)
display(documentation)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://python-visualization.github.io/folium/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Imports:

import folium
from folium import plugins
import ipywidgets
import geocoder
import geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds
import os

# %%
# Basic Maps

folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_629f1a20d948e6e0606c552905e80104 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_629f1a20d948e6e0606c552905e80104&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_629f1a20d948e6e0606c552905e80104 = L.map(
#                 &quot;map_629f1a20d948e6e0606c552905e80104&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fe407236498afd9e2539d897fd2a537 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_629f1a20d948e6e0606c552905e80104);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# map with location start point, zoom level, size and distance scale

map1 = folium.Map(location = [39.739192, -104.990337], zoom_start = 10,width = 500, height = 300, control_scale = True)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7678f4d852f0b89b0cbdb7b7d0b15e3f {
#                     position: relative;
#                     width: 500.0px;
#                     height: 300.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7678f4d852f0b89b0cbdb7b7d0b15e3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7678f4d852f0b89b0cbdb7b7d0b15e3f = L.map(
#                 &quot;map_7678f4d852f0b89b0cbdb7b7d0b15e3f&quot;,
#                 {
#                     center: [39.739192, -104.990337],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7678f4d852f0b89b0cbdb7b7d0b15e3f);
#
#
#
#
#
#             var tile_layer_4a81790176108ff734d0d7b8ce282353 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7678f4d852f0b89b0cbdb7b7d0b15e3f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# another way to change the map size:

from branca.element import Figure

fig = Figure(width = 500, height = 300)
fig.add_child(map1)
fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7678f4d852f0b89b0cbdb7b7d0b15e3f {
#                     position: relative;
#                     width: 500.0px;
#                     height: 300.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7678f4d852f0b89b0cbdb7b7d0b15e3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7678f4d852f0b89b0cbdb7b7d0b15e3f = L.map(
#                 &quot;map_7678f4d852f0b89b0cbdb7b7d0b15e3f&quot;,
#                 {
#                     center: [39.739192, -104.990337],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7678f4d852f0b89b0cbdb7b7d0b15e3f);
#
#
#
#
#
#             var tile_layer_4a81790176108ff734d0d7b8ce282353 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7678f4d852f0b89b0cbdb7b7d0b15e3f);
#
# &lt;/script&gt;" width="500" height="300"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
map2 = folium.Map(location = [39.739192, -104.990337], zoom_start = 10,width = 500, height = 300, control_scale = True)
# Save the Map:
os.getcwd()
map2.save('/home/meta-sapien/Desktop/TDS/Week5/map.html')

# %%
# show the map types using ipywidgets

# widget
select_widget = ipywidgets.Select(
options = ['Open Street Map', 'Terrain', 'Toner', 'Watercolor','Positron', 'Dark Matter'],
value = 'Open Street Map',
description = 'Map Type:',
disabled = False)

# Widget Function

def select(map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location= [39.739192,-104.99037], zoom_start = 12, height = 500))
    if map_type == 'Terrain':
        display(folium.Map(location= [39.739192,-104.99037], tiles = 'Stamen terrain', zoom_start = 12, height = 500))
    if map_type == 'Toner':
        display(folium.Map(location= [39.739192,-104.99037], tiles = 'Stamen toner', zoom_start = 12, height = 500))
    if map_type == 'Watercolor':
        display(folium.Map(location= [39.739192,-104.99037], tiles = 'Stamen Watercolor', zoom_start = 12, height = 500))
    if map_type == 'Positron':
        display(folium.Map(location= [39.739192,-104.99037], tiles = 'CartoDB Positron', zoom_start = 12, height = 500))
    if map_type == 'Dark Matter':
        display(folium.Map(location= [39.739192,-104.99037], tiles = 'CartoDB Dark Matter', zoom_start = 12, height = 500))

# interaction between the widgets and functions:

ipywidgets.interact(select, map_type= select_widget)
# Out:
# interactive(children=(Select(description='Map Type:', options=('Open Street Map', 'Terrain', 'Toner', 'Waterco…
# <function __main__.select(map_type)>

# %%
# Layer Control
# Show the map using the layer control

# map
map_layer_control = folium.Map(location = (38,-98), zoom_start = 2)

# add titles to map
folium.raster_layers.TileLayer('OpenStreerMap').add_to(map_layer_control)
#folium.raster_layers.TileLayer('Stamen Terrain').add_to(map_layer_control)
#folium.raster_layers.TileLayer('Stamen Toner').add_to(map_layer_control)
#folium.raster_layers.TileLayer('Stamen Watercolor').add_to(map_layer_control)
#folium.raster_layers.TileLayer('CartoDB Positron').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Dark Matter').add_to(map_layer_control)

# add layer control to show different maps
folium.LayerControl().add_to(map_layer_control)

# display map
map_layer_control
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [116], in <cell line: 8>()
#       5 map_layer_control = folium.Map(location = (38,-98), zoom_start = 2)
#       7 # add titles to map
# ----> 8 folium.raster_layers.TileLayer('OpenStreerMap').add_to(map_layer_control)
#       9 #folium.raster_layers.TileLayer('Stamen Terrain').add_to(map_layer_control)
#      10 #folium.raster_layers.TileLayer('Stamen Toner').add_to(map_layer_control)
#      11 #folium.raster_layers.TileLayer('Stamen Watercolor').add_to(map_layer_control)
#      12 #folium.raster_layers.TileLayer('CartoDB Positron').add_to(map_layer_control)
#      13 folium.raster_layers.TileLayer('CartoDB Dark Matter').add_to(map_layer_control)
#
# File ~/anaconda3/lib/python3.9/site-packages/folium/raster_layers.py:111, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     109     self.tiles = tiles
#     110     if not attr:
# --> 111         raise ValueError('Custom tiles must have an attribution.')
#     113 self.options = parse_options(
#     114     min_zoom=min_zoom,
#     115     max_zoom=max_zoom,
#    (...)
#     123     **kwargs
#     124 )
#
# ValueError: Custom tiles must have an attribution.

# %%
# mini map, scroll, zoom, full screen

# map 
map5 = folium.Map(location = (19.0760,72.8777), zoom_start = 12)

# plugin for mini map
minimap = plugins.MiniMap(toggle_display= True)

# add minimap to map
map5.add_child(minimap)

# add scroll zoom toggler to map:
plugins.ScrollZoomToggler().add_to(map5)

# add fullscreen to map5
plugins.Fullscreen(position= 'topright').add_to(map5)

# display map
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68ca95b83b21db3838e403336309973b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_5ceae5938f79147e8e1aca13a887009e {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68ca95b83b21db3838e403336309973b&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_5ceae5938f79147e8e1aca13a887009e&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_68ca95b83b21db3838e403336309973b.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_68ca95b83b21db3838e403336309973b = L.map(
#                 &quot;map_68ca95b83b21db3838e403336309973b&quot;,
#                 {
#                     center: [19.076, 72.8777],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ef2d331ab47cea67a50c66189a22bd5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_68ca95b83b21db3838e403336309973b);
#
#
#             var tile_layer_9a6312eeffbdb5c20ce100509a0a4e09 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_b7ecafc26a9fbf358474988d5827795e = new L.Control.MiniMap(
#                 tile_layer_9a6312eeffbdb5c20ce100509a0a4e09,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_68ca95b83b21db3838e403336309973b.addControl(mini_map_b7ecafc26a9fbf358474988d5827795e);
#
#
#             map_68ca95b83b21db3838e403336309973b.scrollEnabled = true;
#
#             map_68ca95b83b21db3838e403336309973b.toggleScroll = function() {
#                 if (this.scrollEnabled) {
#                     this.scrollEnabled = false;
#                     this.scrollWheelZoom.disable();
#                 } else {
#                     this.scrollEnabled = true;
#                     this.scrollWheelZoom.enable();
#                 }
#             };
#             map_68ca95b83b21db3838e403336309973b.toggleScroll();
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_68ca95b83b21db3838e403336309973b);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# MARKERS

folium.Marker?

# %%
# geocode address and place marker on map

# map 
map_mum = folium.Map(location = (19.0760,72.8777), zoom_start = 12)

# get the location information for address
address = geocoder.osm('IIT, Bombay')
#print(address.lat)

# address lat and long
address_latlong  = [address.lat, address.lng]

# add market to map
folium.Marker(address_latlong, popup = 'Powai Lake', tooltip = 'click').add_to(map_mum)

# display map
map_mum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4adb324af67f37222f32e56758434d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4adb324af67f37222f32e56758434d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a4adb324af67f37222f32e56758434d9 = L.map(
#                 &quot;map_a4adb324af67f37222f32e56758434d9&quot;,
#                 {
#                     center: [19.076, 72.8777],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbf10a5e5693e83f57a896ebd3053c6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a4adb324af67f37222f32e56758434d9);
#
#
#             var marker_ece3e5ba7e9f0b9dfe041c20630c38ae = L.marker(
#                 [19.13261855, 72.91497912536826],
#                 {}
#             ).addTo(map_a4adb324af67f37222f32e56758434d9);
#
#
#         var popup_c715486b0f9dbebbe1ac28ca24701a20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bddbdbbe9b166803e0eeb2637709cbdf = $(`&lt;div id=&quot;html_bddbdbbe9b166803e0eeb2637709cbdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Powai Lake&lt;/div&gt;`)[0];
#             popup_c715486b0f9dbebbe1ac28ca24701a20.setContent(html_bddbdbbe9b166803e0eeb2637709cbdf);
#
#
#         marker_ece3e5ba7e9f0b9dfe041c20630c38ae.bindPopup(popup_c715486b0f9dbebbe1ac28ca24701a20)
#         ;
#
#
#
#
#             marker_ece3e5ba7e9f0b9dfe041c20630c38ae.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# get airports dataframe using vega dataset

airports = vds.airports()
airports = airports[:25]
airports.head()
# Out:
#   iata                  name              city state country   latitude  \
# 0  00M               Thigpen       Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#     longitude
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %%
# Placing multiple markers on the map using the dataframe

# create map
map6 = folium.Map(location = (38,-98), zoom_start = 4)

# plot the airport locations
for index, row in airports.iterrows():
    folium.Marker(location = (row.loc['latitude'], row.loc['longitude']),
                  popup = row.loc['name'] + ' ' + row.loc['city'] + ' ' + row.loc['state'],
                  tooltip = 'click').add_to(map6)    

# display map
map6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5e68eb4779922e34498026bcac82481 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5e68eb4779922e34498026bcac82481&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e5e68eb4779922e34498026bcac82481 = L.map(
#                 &quot;map_e5e68eb4779922e34498026bcac82481&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8bdf93bb68bbe2a9fe80fab10b72e74 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e5e68eb4779922e34498026bcac82481);
#
#
#             var marker_7b5353ba870b001361523822be7c0f0c = L.marker(
#                 [31.95376472, -89.23450472],
#                 {}
#             ).addTo(map_e5e68eb4779922e34498026bcac82481);
#
#
#         var popup_a9e5583af717c701e803a6e89f603ae4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2f1448781e33c8609ba3ba2aa5a1a78c = $(`&lt;div id=&quot;html_2f1448781e33c8609ba3ba2aa5a1a78c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen Bay Springs MS&lt;/div&gt;`)[0];
#             popup_a9e5583af717c701e803a6e89f603ae4.setContent(html_2f1448781e33c8609ba3ba2aa5a1a78c);
#
#
#         marker_7b5353ba870b001361523822be7c0f0c.bindPopup(popup_a9e5583af717c701e803a6e89f603ae4)
#         ;
#
#
#
#
#             marker_7b5353ba870b001361523822be7c0f0c.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_777b769e2db5769f03f82ac5ba482503 = L.marker(
#                 [30.68586111, -95.01792778],
#                 {}
#             ).addTo(map_e5e68eb4779922e34498026bcac82481);
#
#
#         var popup_6cc83ac5341549ddb1ab07f62d819679 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_af90cdc99bfff6a8972af1e6cb05c2bb = $(`&lt;div id=&quot;html_af90cdc99bfff6a8972af1e6cb05c2bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal Livingston TX&lt;/div&gt;`)[0];
#             popup_6cc83ac5341549ddb1ab07f62d819679.setContent(html_af90cdc99bfff6a8972af1e6cb05c2bb);
#
#
#         marker_777b769e2db5769f03f82ac5ba482503.bindPopup(popup_6cc83ac5341549ddb1ab07f62d819679)
#         ;
#
#
#
#
#             marker_777b769e2db5769f03f82ac5ba482503.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8b1a409cd08a3d9c519db31d048ab568 = L.marker(
#                 [38.94574889, -104.5698933],
#                 {}
#             ).addTo(map_e5e68eb4779922e34498026bcac82481);
#
#
#         var popup_9d402d0ae11d9b5a0e904aa6af51bd15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b13e64ea41564d6f1ada143df8e8e81f = $(`&lt;div id=&quot;html_b13e64ea41564d6f1ada143df8e8e81f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake Colorado Springs CO&lt;/div&gt;`)[0];
#             popup_9d402d0ae11d9b5a0e904aa6af51bd15.setContent(html_b13e64ea41564d6f1ada143df8e8e81f);
#
#
#         marker_8b1a409cd08a3d9c519db31d048ab568.bindPopup(popup_9d402d0ae11d9b5a0e904aa6af51bd15)
#         ;
#
#
#
#
#             marker_8b1a409cd08a3d9c519db31d048ab568.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a07561fd471be7f945b3de71616bd09c = L.marker(
#                 [42.74134667, -78.05208056],
#                 {}
#             ).addTo(map_e5e68eb4779922e34498026bcac82481);
#
#
#         var popup_638e5cf3fb46bb418489a24c9296c3a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7ef6d07d4ce2fd694e5d881cbbdea14e = $(`&lt;div id=&quot;html_7ef6d07d4ce2fd694e5d881cbbdea14e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw Perry NY&lt;/div&gt;`)[0];
#             popup_638e5cf3fb46bb418489a24c9296c3a4.setContent(html_7ef6d07d4ce2fd694e5d881cbbdea14e);
#
#
#         marker_a07561fd471be7f945b3de71616bd09c.bindPopup(popup_638e5cf3fb46bb418489a24c9296c3a4)
#         ;
#
#
#
#
#             marker_a07561fd471be7f945b3de71616bd09c.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c81547f1a22815f50c23d6437328a6e4 = L.marker(
#                 [30.6880125, -81.90594389],
#                 {}
#             ).addTo(map_e5e68eb4779922e34498026bcac82481);
#
#
#         var popup_36

# %%
# Custom Markers

# Map 
map_cm_fa = folium.Map(location = [38, -98], zoom_start = 4)

# add custom marker to map
folium.Marker(location = (38,-98),
             popup = 'popup',
             icon = folium.Icon(color = 'green', icon = 'bolt', prefix = 'fa')).add_to(map_cm_fa)
# display the map
map_cm_fa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_566a0d9546cd996d1d7a41f8a406637d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_566a0d9546cd996d1d7a41f8a406637d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_566a0d9546cd996d1d7a41f8a406637d = L.map(
#                 &quot;map_566a0d9546cd996d1d7a41f8a406637d&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d77afec61300ee4228bff0482e57ad0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_566a0d9546cd996d1d7a41f8a406637d);
#
#
#             var marker_be7f58f455cf22070d8b0338d9bb2a66 = L.marker(
#                 [38.0, -98.0],
#                 {}
#             ).addTo(map_566a0d9546cd996d1d7a41f8a406637d);
#
#
#             var icon_7466fa43169c48210bd59a835d76f098 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_be7f58f455cf22070d8b0338d9bb2a66.setIcon(icon_7466fa43169c48210bd59a835d76f098);
#
#
#         var popup_849b612afbd8743135dad21917c35ccb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_209f24368867c964ec34f360abcefc52 = $(`&lt;div id=&quot;html_209f24368867c964ec34f360abcefc52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#             popup_849b612afbd8743135dad21917c35ccb.setContent(html_209f24368867c964ec34f360abcefc52);
#
#
#         marker_be7f58f455cf22070d8b0338d9bb2a66.bindPopup(popup_849b612afbd8743135dad21917c35ccb)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Circle Markers

# map
map_circle = folium.Map(location = [38,-98], zoom_start = 4)

# radius of the circle
folium.Circle(radius = 10000, location = [38,-98], color = 'green').add_to(map_circle)
# radius in meters thus it remains fixed

# circle of a fixed size with radius specified in pixels
folium.CircleMarker(location = [39, -105], radius = 25, color='blue', fill_color = 'yellow').add_to(map_circle)
# radius specified in pixels so remains the same size
map_circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13 = L.map(
#                 &quot;map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94570410fb8d7dd1a500e9f6f01651c5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13);
#
#
#             var circle_e35b9ed464d6329154feb22e31b3fab8 = L.circle(
#                 [38.0, -98.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13);
#
#
#             var circle_marker_dd9da15e5a4f2ae0766b1647fd42aba6 = L.circleMarker(
#                 [39.0, -105.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fe1bda84c9ef6b8f5dc3c9e1d2c3d13);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# route 

# map
map_plot_route = folium.Map(location = (38,-98), zoom_start = 4)

# route location
# can use list of lists or list of tuples
route_lat_long = [[34.041008, -118.246653],
                 [36.169726,-115.123996],
                 [39.739448,-104.992450],
                 [41.878765,-87.643267],
                 [40.782949,-73.969559]]

# add route to map
folium.PolyLine(route_lat_long).add_to(map_plot_route)

# display the map
map_plot_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed1f890b84349df510b92248dcda6c3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed1f890b84349df510b92248dcda6c3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ed1f890b84349df510b92248dcda6c3c = L.map(
#                 &quot;map_ed1f890b84349df510b92248dcda6c3c&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ad878e16c19e59e79ab104313a59594 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed1f890b84349df510b92248dcda6c3c);
#
#
#             var poly_line_1631e34de5f22eb13ccc1e95539365d2 = L.polyline(
#                 [[34.041008, -118.246653], [36.169726, -115.123996], [39.739448, -104.99245], [41.878765, -87.643267], [40.782949, -73.969559]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed1f890b84349df510b92248dcda6c3c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ant path route

# uses import - from folium import plugins

# map 
map_ant = folium.Map(location = [38,-98], zoom_start = 4)

# add ant path route to map
plugins.AntPath(route_lat_long).add_to(map_ant)

# display the map
map_ant
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d77d346f2e1fe89fd7c7ea8bd778f05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d77d346f2e1fe89fd7c7ea8bd778f05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6d77d346f2e1fe89fd7c7ea8bd778f05 = L.map(
#                 &quot;map_6d77d346f2e1fe89fd7c7ea8bd778f05&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3db5a2bafa2f7b0bcee948f26e3bb524 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6d77d346f2e1fe89fd7c7ea8bd778f05);
#
#
#             ant_path_a81a9be859b45835bb9f21a7c74b1c83 = L.polyline.antPath(
#               [[34.041008, -118.246653], [36.169726, -115.123996], [39.739448, -104.99245], [41.878765, -87.643267], [40.782949, -73.969559]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: [10, 20], &quot;dashOffset&quot;: null, &quot;delay&quot;: 400, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_6d77d346f2e1fe89fd7c7ea8bd778f05);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Overlay GeoJSON Layers

# %%
# use link or a file
# use geojson.io to create custom geojson files
# can also use folium Draw control to create geojson files 
# convert the shape files to geojson using QGIS

# map
map_geojson = folium.Map(location = [39.77, -86.15], zoom_start = 7)

# add geojson file to the map
folium.GeoJson('indiana_outline_map.geojson', name = 'geojson indiana').add_to(map_geojson)

# add layer control to map(allows the layer to be turn on and off)
folium.LayerControl().add_to(map_geojson)

# display map
map_geojson
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_195aabdeb9c6b7923947b4d2a8adb181 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_195aabdeb9c6b7923947b4d2a8adb181&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_195aabdeb9c6b7923947b4d2a8adb181 = L.map(
#                 &quot;map_195aabdeb9c6b7923947b4d2a8adb181&quot;,
#                 {
#                     center: [39.77, -86.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2386d3aa97368f4c7a0ccc795914005a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_195aabdeb9c6b7923947b4d2a8adb181);
#
#
#
#         function geo_json_82e44c480d2a05e0cbf91cf6fd9e61d0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_82e44c480d2a05e0cbf91cf6fd9e61d0 = L.geoJson(null, {
#                 onEachFeature: geo_json_82e44c480d2a05e0cbf91cf6fd9e61d0_onEachFeature,
#
#         });
#
#         function geo_json_82e44c480d2a05e0cbf91cf6fd9e61d0_add (data) {
#             geo_json_82e44c480d2a05e0cbf91cf6fd9e61d0
#                 .addData(data)
#                 .addTo(map_195aabdeb9c6b7923947b4d2a8adb181);
#         }
#             geo_json_82e44c480d2a05e0cbf91cf6fd9e61d0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-87.528076171875, 41.77131167976407], [-87.550048828125, 39.342794408952365], [-87.62695312499999, 39.2832938689385], [-87.56103515625, 39.20671884491848], [-87.64892578125, 39.155622393423215], [-87.615966796875, 39.08743603215884], [-87.56103515625, 39.027718840211605], [-87.57202148437499, 38.96795115401593], [-87.51708984375, 38.90813299596705], [-87.56103515625, 38.84826438869913], [-87.4951171875, 38.77978137804918], [-87.506103515625, 38.70265930723801], [-87.593994140625, 38.66835610151506], [-87.62695312499999, 38.59970036588819], [-87.69287109375, 38.53957267203905], [-87.64892578125, 38.487994609214795], [-87.73681640625, 38.47079371120379], [-87.747802734375, 38.40194908237822], [-87.81372070312499, 38.35888785866677], [-87.82470703125, 38.28131307922969], [-87.890625, 38.324420427006544], [-87.945556640625, 38.26406296833961], [-87.989501953125, 38.229550455326134], [-87.91259765625, 38.16047628099622], [-88.00048828124999, 38.108627664321276], [-87.9345703125, 38.08268954483802], [-88.0224609375, 38.048091067457236], [-88.0224609375, 37.98750437106374], [-88.0224609375, 37.91820111976663], [-88.11035156249999, 37.91820111976663], [-88.05541992187499, 37.86618078529668], [-88.077392578125, 37.80544394934271], [-88.00048828124999, 37.80544394934271], [-87.9345703125, 37.75334401310656], [-87.890625, 37.82280243352756], [-87.923583984375, 37.89219554724434], [-87.901611328125, 37.96152331396614], [-87.82470703125, 37.87485339352928], [-87.725830078125, 37.89219554724434], [-87.659912109375, 37.87485339352928], [-87.64892578125, 37.82280243352756], [-87.57202148437499, 37.87485339352928], [-87.615966796875, 37.94419750075404], [-87.528076171875, 37.91820111976663], [-87.418212890625, 37.94419750075404], [-87.264404296875, 37.87485339352928], [-87.154541015625, 37.84015683604136], [-87.099609375, 37.76202988573211], [-87.0556640625, 37.83148014503288], [-87.01171875, 37.91820111976663], [-86.890869140625, 37.93553306183642], [-86.81396484375, 37.996162679728116], [-86.72607421875, 37.88352498087131], [-86.649169921875, 37.90953361677018], [-86.649169921875, 37.83148014503288], [-86.572265625, 37.86618078529668], [-86.561279296875, 37.93553306183642], [-86.47338867187499, 37.92686760148135], [-86.50634765625, 38.039438891821746], [-86.4404296875, 38.06539235133249], [-86.46240234375, 38.14319750166766], [-86.3525390625, 38.1172716583054], [-86.36352539062499, 38.20365531807149], [-86.2646484375, 38.14319750166766], [-86.253662109375, 38.048091067457236], [-86.15478515625, 38.004819966413194], [-86.06689453125, 37.996162679728116], [-86.044921875, 37.94419750075404], [-85.98999023437499, 38.013476231041935], [-85.902099609375, 38.048091067457236], [-85.89111328125, 38.16047628099622], [-85.858154296875, 38.25543637637947], [-85.78125, 38.298559092254344], [-85.682373046875, 38.28993659801203], [-85.594482421875, 38.42777351132902], [-85.517578125, 38.453588708941375], [-85.418701171875, 38.522384090200845], [-85.4296875, 38.62545397209084], [-85.440673828125, 38.7283759182398], [-85.341796875, 38.736946065676], [-85.25390625, 38.736946065676], [-85.177001953125, 38.676933444637925], [-85.05615234375, 38.736946065676], [-84.935302734375, 38.77978137804918], [-84.803466796875, 38.77978137804918], [-84.825439453125, 38.85682013474361], [-84.759521484375, 38.89103282648849], [-84.88037109375, 38.93377552819722], [-84.803466796875, 39.00211029922512], [-84.92431640625, 39.07890809706475], [-84.803466796875, 39.13006024213511], [-84.814453125, 41.7631174470059], [-87.48413

# %% [markdown]
# # Subgroups with geoJSON

# %%
# map
map_with_subgroups = folium.Map(location = [39.77, -86.15], zoom_start = 7)

# all subgroups
all_subgroups = folium.FeatureGroup(name= 'all sales regions')
map_with_subgroups.add_child(all_subgroups)

# subgroup 1
sales_region1 = plugins.FeatureGroupSubGroup(all_subgroups, 'sales region 1')
map_with_subgroups.add_child(sales_region1)

# subgroup 2
sales_region2 = plugins.FeatureGroupSubGroup(all_subgroups, 'sales region 2')
map_with_subgroups.add_child(sales_region2)

# subgroup 3
sales_region3 = plugins.FeatureGroupSubGroup(all_subgroups, 'sales region 3')
map_with_subgroups.add_child(sales_region3)

# Pull in all the geojson layers and add to the map
folium.GeoJson('sales_region1.geojson').add_to(sales_region1)
folium.GeoJson('sales_region2.geojson').add_to(sales_region2)
folium.GeoJson('sales_region3.geojson').add_to(sales_region3)

# add layer control to map(allows layers to be turned on or off)
folium.LayerControl(collapsed = False).add_to(map_with_subgroups)

# display map
map_with_subgroups
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29a8b9e0f01aa1011c82be22cce062ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29a8b9e0f01aa1011c82be22cce062ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_29a8b9e0f01aa1011c82be22cce062ed = L.map(
#                 &quot;map_29a8b9e0f01aa1011c82be22cce062ed&quot;,
#                 {
#                     center: [39.77, -86.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21bb27b95c1dd30e478fd6d1ac6cd3f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_29a8b9e0f01aa1011c82be22cce062ed);
#
#
#             var feature_group_c4cb2d30a914d04570ba7d14e92e0a0c = L.featureGroup(
#                 {}
#             ).addTo(map_29a8b9e0f01aa1011c82be22cce062ed);
#
#
#             var feature_group_sub_group_b85485b898b8db86433ae232597b90f0 = L.featureGroup.subGroup(
#                 feature_group_c4cb2d30a914d04570ba7d14e92e0a0c
#             );
#             feature_group_sub_group_b85485b898b8db86433ae232597b90f0.addTo(map_29a8b9e0f01aa1011c82be22cce062ed);
#
#
#
#         function geo_json_2c2a0c499213f1277881f10f1f92a502_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2c2a0c499213f1277881f10f1f92a502 = L.geoJson(null, {
#                 onEachFeature: geo_json_2c2a0c499213f1277881f10f1f92a502_onEachFeature,
#
#         });
#
#         function geo_json_2c2a0c499213f1277881f10f1f92a502_add (data) {
#             geo_json_2c2a0c499213f1277881f10f1f92a502
#                 .addData(data)
#                 .addTo(feature_group_sub_group_b85485b898b8db86433ae232597b90f0);
#         }
#             geo_json_2c2a0c499213f1277881f10f1f92a502_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.4788818359375, 40.04443758460856], [-86.4788818359375, 40.01289077952615], [-86.48712158203125, 39.97922477476734], [-86.517333984375, 39.95606977009003], [-86.5338134765625, 39.930800820752765], [-86.5338134765625, 39.8992015115692], [-86.54205322265625, 39.85282948915942], [-86.54754638671875, 39.787433886224385], [-86.53106689453125, 39.75999140525313], [-86.5228271484375, 39.72831341029745], [-86.5228271484375, 39.690280594818034], [-86.4898681640625, 39.67971220315972], [-86.48162841796875, 39.58029027440865], [-86.4678955078125, 39.55700068337126], [-86.46240234375, 39.53158493558714], [-86.45416259765625, 39.50404070558415], [-86.43768310546875, 39.487084981687495], [-86.45690917968749, 39.436192999314066], [-86.5228271484375, 39.40648882684979], [-86.48162841796875, 39.37252570201878], [-86.25640869140625, 39.37464888160068], [-86.16302490234375, 39.41497702499074], [-85.97900390625, 39.41497702499074], [-85.94329833984375, 39.50192146626985], [-85.94879150390625, 39.66914219401813], [-85.9130859375, 39.73887436009365], [-85.9185791015625, 39.825413103424786], [-85.9185791015625, 39.99605985169435], [-85.92681884765624, 40.092781012494065], [-86.07513427734374, 40.096983167279575], [-86.4129638671875, 40.057052221322], [-86.4678955078125, 40.04864272291728]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.46785259246826, 40.04867557453912], [-86.4788818359375, 40.04450329188953]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var feature_group_sub_group_5e18f2d0266afee9f60683942ec40613 = L.featureGroup.subGroup(
#                 feature_group_c4cb2d30a914d04570ba7d14e92e0a0c
#             );
#             feature_group_sub_group_5e18f2d0266afee9f60683942ec40613.addTo(map_29a8b9e0f01aa1011c82be22cce062ed);
#
#
#
#         function geo_json_b0fa17447f72a4ae240b2a1c492b9043_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b0fa17447f72a4ae240b2a1c492b9043 = L.geoJson(null, {
#                 onEachFeature: geo_json_b0fa17447f72a4ae240b2a1c492b9043_onEachFeature,
#
#         });
#
#         function geo_json_b0fa17447f72a4ae240b2a1c492b9043_add (data) {
#             geo_json_b0fa17447f72a4ae240b2a1c492b9043
#                 .addData(data)
#                 .addTo(feature_group_sub_group_5e18f2d0266afee9f60683942ec40613);
#         }
#             geo_json_b0fa17447f72a4ae240b2a1c492b9043_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-85.33905029296875, 41.1290213474951], [-85.3363037109375, 41.01099329360268], [-85.34454345703125, 40.994410999439516], [-85.352783203125, 40.977824533189505], [-85.

# %% [markdown]
# # Choropleth Maps

# %%
import json

with oprn

# %% [markdown]
# @source: Ryan Loonan
